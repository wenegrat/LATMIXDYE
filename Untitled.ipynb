# %%
#import cmocean
import matplotlib.pyplot as plt

# %%
import cmocean.plots as cmplot
import cmocean.cm as cmo

# %%
cmplot.test(cmo.thermal)
cmplot.test(cmap = plt.cm.get_cmap('gnuplot'))

# %%
cmplot.wrap_viscm(cmo.thermal)

# %%
cmplot.wrap_viscm(plt.cm.get_cmap('gnuplot'))
